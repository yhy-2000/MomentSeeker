# %%
import json

# %%
with open("/share/huaying/long_video/video_retriever/benchmark/retrieval/corpus_level_tv2v_youtube/eval_tv2v.jsonl", "r") as f:
    data = json.load(f)

# %%
data[10]
# Out:
# {'qry_text': '<video> Find a man doing the opposite task.',
#  'qry_img_path': '',
#  'qry_video_path': '/share/junjie/shuyan/video_traindata/liwei_youtube_videos/videos/youtube_video_2024/ytb_io9d4i7A3bA.mp4',
#  'tgt_text': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
# ...

# %%
data[0].keys()
# Out:
# dict_keys(['qry_text', 'qry_img_path', 'qry_video_path', 'tgt_text', 'tgt_img_path', 'tgt_video_path'])
